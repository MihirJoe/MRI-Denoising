# %% [markdown]
# ___
# # **Starter code for BME 5710 project**
# ## Instructor -- Rizwan Ahmad (ahmad.46@osu.edu)
# ## BME5710 -- Spring 2024

# %% [markdown]
# ___
# ### Import libraries and sub-libraries.

# %%
import os
import numpy as np
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import matplotlib.pyplot as plt
from torchvision.transforms import functional as TF
from skimage.metrics import structural_similarity as ssim
import tifffile

# %% [markdown]
# ___
# ### Calling a custom code to change the default font for figures to `Computer Modern`. (Optional)

# %%
from fontsetting import font_cmu
plt = font_cmu(plt)

# %% [markdown]
# ___
# ### Check the hardware that is at your disposal

# %%
device = torch.device('gpu' if torch.cuda.is_available() else 'cpu')
print('Device available:', device)
# Out:
# Device available: cpu

# %% [markdown]
# ___
# ### Read training & validation data from `data/train-clean-tif` and `data/val-clean-tif`

# %%
# Loading TIFF images
class TIFFDataset(Dataset):
    def __init__(self, directory, transform=None):
        self.directory = directory
        self.transform = transform
        self.filenames = [f for f in os.listdir(directory) if f.endswith('.tif')]

    def __len__(self):
        return len(self.filenames)

    def __getitem__(self, idx):
        img_path = os.path.join(self.directory, self.filenames[idx])
        image = Image.open(img_path)
        if self.transform: # Dynamically apply data transformation
            image = self.transform(image)
        return image

# Create a transform to convert the images to PyTorch tensors
transform = transforms.Compose([
    transforms.ToTensor()
])

# Create the dataset for training images
train_dataset = TIFFDataset('train-clean-tif', transform=transform)

# Create the dataset for the validation images
val_dataset = TIFFDataset('val-clean-tif', transform=transform)

# Function to create data loader
def create_loader(train_dataset, batch_size):
    torch.manual_seed(0)  # For reproducibility of random numbers in PyTorch
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)  # Creates a training DataLoader from this Dataset
    return train_loader

train_dataset_size = len(train_dataset)
print('Number of images in the train dataset:', train_dataset_size)

val_dataset_size = len(val_dataset)
print('Number of images in the validation dataset:', val_dataset_size)
# Out:
# Number of images in the train dataset: 52
# Number of images in the validation dataset: 16

# %% [markdown]
# ___
# ### Define a denoising network
#
# #### Here, I have defined a trivial network, which has only one convolutional layer and no activation function. We are essentially doing linear filtering.

# %%
class TrivialNet(nn.Module):
    def __init__(self):
        super(TrivialNet, self).__init__()
        self.conv = nn.Conv2d(in_channels=1, out_channels=1, kernel_size=3, padding=1)

    def forward(self, x):
        x = self.conv(x)
        return x

# %% [markdown]
# #### MihirNet1

# %%
class MihirNet1(nn.Module):
  def __init__(self):
    super(MihirNet1, self).__init__()
    self.k1 = 3 # TODO: change kernel size
    self.conv1 = nn.Sequential(
      nn.Conv2d(1, 256, kernel_size=self.k1, padding=(1,1)),
      nn.MaxPool2d(kernel_size=(2,2), stride=(2,2)),
      nn.ReLU()) # size: 128x128
    # TODO: change activation to LeakyReLU
    # self.conv1b = nn.Sequential(
    #   nn.Conv2d(16, 32, kernel_size=self.k1, padding=(1,1)),
    #   nn.MaxPool2d(kernel_size=(2,2), stride=(2,2)),
    #   nn.ReLU())
    
    # self.conv1c = nn.Sequential(
    #   nn.Conv2d(128, 256, kernel_size=self.k1, padding=(1,1)),
    #   nn.MaxPool2d(kernel_size=(2,2), stride=(2,2)),
    #   nn.ReLU())
    
    self.conv2 = nn.Sequential(
      nn.Conv2d(256, 512, kernel_size=self.k1, padding=(1,1)),
      nn.MaxPool2d(kernel_size=(2,2), stride=(2,2)),
      nn.ReLU())
    
    self.conv2_skip = nn.Sequential(
      nn.Conv2d(256, 512, kernel_size=self.k1, padding=(1,1)),
      nn.ReLU())
    
    self.conv3 = nn.Sequential(
      nn.Conv2d(512, 512, kernel_size=self.k1, padding=(1,1)),
      nn.ReLU())
    
    self.conv4 = nn.Sequential(
      nn.Conv2d(768, 256, kernel_size=self.k1, padding=1),
      nn.ReLU())
    
    self.conv5 = nn.Sequential(
      nn.Conv2d(128, 1, kernel_size=self.k1, padding=1),
      nn.ReLU())
    
    self.up1 = nn.ConvTranspose2d(in_channels=512, out_channels=256, kernel_size=2, stride=2)
    self.up2 = nn.ConvTranspose2d(in_channels=512, out_channels=128, kernel_size=2, stride=2)
    

  def forward(self, x):

    skip1 = self.conv1(x)

    x = self.conv1(x)
    print(f"conv1 size: {x.shape}")
    # x = self.conv1b(x)
    # print(f"conv1b size: {x.shape}")
    # x = self.conv1c(x)
    # print(f"conv1c size: {x.shape}")

    skip2 = self.conv2_skip(x)
    print(f"skip2 size: {x.shape}")

    x = self.conv2(x)
    print(f"conv2 size: {x.shape}")

    x = self.conv3(x)
    print(f"conv3 size: {x.shape}")
    # print(f"0: {x.shape}")

    x = self.up1(x)
    print(f"upsam1 size: {x.shape}")

    x = torch.cat((x, skip2))  # Concatenate along channel dimension
    print(f"concat1 output: {x.shape}")
    x = self.conv4(x)
    # x = self.conv5(x)
    # print(f"2: {x.shape}")
    
    # print(f"3: {x.shape}")
    x = torch.cat((x, skip1))  # Concatenate along channel dimension
    print(f"concat output: {x.shape}")
    x = self.up2(x)
    print(f"upsamp2 size: {x.shape}")
    
    x = self.conv5(x)
    # print(f"4: {x.shape}")
    
    return x

# %% [markdown]
# #### MihirNet2

# %%
class MihirNet2(nn.Module):
  def __init__(self):
    super(MihirNet2, self).__init__()

    self.printOutput = False

    self.k1 = 3 # TODO: change kernel size
    
    self.conv1_skip = nn.Sequential(
      nn.Conv2d(1, 64, kernel_size=self.k1, padding=(1,1)),
      # nn.BatchNorm1d(256),
      nn.MaxPool2d(kernel_size=(2,2), stride=(2,2)),
      nn.ReLU()) # size: 128x128
    
    self.conv1 = nn.Sequential(
      nn.Conv2d(1, 128, kernel_size=self.k1, padding=(1,1)),
      # nn.BatchNorm1d(16),
      nn.MaxPool2d(kernel_size=(2,2), stride=(2,2)),
      nn.ReLU()) # size: 128x128
    
    
    # TODO: change activation to LeakyReLU
    self.conv1b = nn.Sequential(
      nn.Conv2d(64, 128, kernel_size=self.k1, padding=(1,1)),
      # nn.BatchNorm1d(32),
      # nn.MaxPool2d(kernel_size=(2,2), stride=(2,2)),
      nn.Dropout(),
      nn.ReLU())
    
    self.conv1c = nn.Sequential(
      nn.Conv2d(128, 128, kernel_size=self.k1, padding=(1,1)),
      # nn.BatchNorm1d(64),
      # nn.MaxPool2d(kernel_size=(2,2), stride=(2,2)),
      nn.Dropout(),
      nn.ReLU())
    
    self.conv2 = nn.Sequential(
      nn.Conv2d(128, 256, kernel_size=self.k1, padding=(1,1)),
      # nn.BatchNorm1d(512),
      nn.MaxPool2d(kernel_size=(2,2), stride=(2,2)),
      nn.ReLU())
    
    self.conv2_skip = nn.Sequential(
      nn.Conv2d(128, 128, kernel_size=self.k1, padding=(1,1)),
      nn.MaxPool2d(kernel_size=(2,2), stride=(2,2)),
      nn.ReLU())
    
    self.conv3 = nn.Sequential(
      nn.Conv2d(256, 512, kernel_size=self.k1, padding=(1,1)),
      nn.MaxPool2d(kernel_size=(2,2), stride=(2,2)),
      nn.ReLU())
    
    self.conv4a = nn.Sequential(
      nn.Conv2d(512, 512, kernel_size=self.k1, padding=1),
      nn.MaxPool2d(kernel_size=(2,2), stride=(2,2)),
      nn.ReLU())
    
    self.conv4a2 = nn.Sequential(
      nn.Conv2d(512, 512, kernel_size=self.k1, padding=1),
      # nn.MaxPool2d(kernel_size=(2,2), stride=(2,2)),
      nn.ReLU())
    
    self.conv4a3 = nn.Sequential(
      nn.Conv2d(512, 512, kernel_size=self.k1, padding=1),
      # nn.MaxPool2d(kernel_size=(2,2), stride=(2,2)),
      nn.ReLU())
    
    self.conv4b = nn.Sequential(
      nn.Conv2d(512, 256, kernel_size=self.k1, padding=1),
      nn.ConvTranspose2d(in_channels=256, out_channels=256, kernel_size=2, stride=2),
      nn.ReLU())
    
    self.conv4c = nn.Sequential(
    nn.Conv2d(256, 128, kernel_size=self.k1, padding=1),
    nn.ConvTranspose2d(in_channels=128, out_channels=128, kernel_size=2, stride=2),
    nn.ReLU())
    
    # skip connection 2 gets added before this step
    
    self.conv5a = nn.Sequential(
      nn.Conv2d(128, 64, kernel_size=self.k1, padding=1),
      nn.ConvTranspose2d(in_channels=64, out_channels=64, kernel_size=2, stride=2),
      nn.ReLU())
    
    # skip connection 1 gets added before this step
    self.conv5b = nn.Sequential(
      nn.Conv2d(128, 64, kernel_size=self.k1, padding=1),
      nn.ConvTranspose2d(in_channels=64, out_channels=32, kernel_size=2, stride=2),
      nn.ReLU())

    self.conv5c = nn.Sequential(
      nn.Conv2d(32, 1, kernel_size=self.k1, padding=1),
      nn.ReLU())
    
    
    self.up1 = nn.ConvTranspose2d(in_channels=512, out_channels=256, kernel_size=2, stride=2)
    self.up2 = nn.ConvTranspose2d(in_channels=512, out_channels=128, kernel_size=2, stride=2)
    

  def forward(self, x):

    skip1 = self.conv1_skip(x) # skips to conv 5a
    if self.printOutput:
      print(f"skip1 size: {skip1.shape}")

    x = self.conv1(x)
    # print(f"conv1 size: {x.shape}")
    # x = self.conv1b(x)
  
    # print(f"conv1b size: {x.shape}")
    # x = self.conv1c(x)
    # print(f"conv1c size: {x.shape}")

    # skip2 = self.conv2_skip(x)

    # if self.printOutput:
    #   print(f"skip2 size: {skip2.shape}")
    x = self.conv2(x)
    # print(f"conv2 size: {x.shape}")
    

    x = self.conv3(x)
    # print(f"conv3 size: {x.shape}")

    x = self.conv4a(x)
    # print(f"conv4asize: {x.shape}")
    x = self.conv4a2(x)

    x = self.conv4a3(x)
    
    # x = self.up1(x)
    # print(f"upsam1 size: {x.shape}")

    x = self.conv4b(x)
    if self.printOutput:
      print(f"conv4b size: {x.shape}")

    x = self.conv4c(x)
    if self.printOutput:
      print(f"conv4c size: {x.shape}")

    # x = torch.cat((x, skip2))  # Concatenate along channel dimension
    if self.printOutput:
      print(f"concat output: {x.shape}")
    
    x = self.conv5a(x)
    if self.printOutput:
      print(f"conv5a: {x.shape}")

    x = torch.cat((x, skip1))  # Concatenate along channel dimension
    if self.printOutput:  
      print(f"concat output: {x.shape}")
    
    x = self.conv5b(x)
    if self.printOutput:
      print(f"conv5b: {x.shape}")

    x = self.conv5c(x)
    if self.printOutput:
      print(f"conv5c: {x.shape}")
    
    return x
  

  #TODO: 
  # - add more skip connections
  # - add batch norm
  # - add dropout
  # - change learning rate

# %% [markdown]
# ### MihirNet2 (75 epochs)

# %%
class MihirNet2(nn.Module):
  def __init__(self):
    super(MihirNet2, self).__init__()
    self.k1 = 3 # TODO: change kernel size
    
    self.conv1_skip = nn.Sequential(
      nn.Conv2d(1, 128, kernel_size=self.k1, padding=(1,1)),
      # nn.BatchNorm1d(256),
      nn.MaxPool2d(kernel_size=(2,2), stride=(2,2)),
      nn.ReLU()) # size: 128x128
    
    self.conv1 = nn.Sequential(
      nn.Conv2d(1, 16, kernel_size=self.k1, padding=(1,1)),
      # nn.BatchNorm1d(16),
      nn.MaxPool2d(kernel_size=(2,2), stride=(2,2)),
      nn.ReLU()) # size: 128x128
    
    
    # TODO: change activation to LeakyReLU
    self.conv1b = nn.Sequential(
      nn.Conv2d(16, 32, kernel_size=self.k1, padding=(1,1)),
      # nn.BatchNorm1d(32),
      # nn.MaxPool2d(kernel_size=(2,2), stride=(2,2)),
      nn.ReLU())
    
    self.conv1c = nn.Sequential(
      nn.Conv2d(32, 64, kernel_size=self.k1, padding=(1,1)),
      # nn.BatchNorm1d(64),
      # nn.MaxPool2d(kernel_size=(2,2), stride=(2,2)),
      nn.ReLU())
    
    self.conv1d = nn.Sequential(
      nn.Conv2d(64, 128, kernel_size=self.k1, padding=(1,1)),
      # nn.BatchNorm1d(64),
      # nn.MaxPool2d(kernel_size=(2,2), stride=(2,2)),
      nn.ReLU())
    
    self.conv2 = nn.Sequential(
      nn.Conv2d(64, 128, kernel_size=self.k1, padding=(1,1)),
      # nn.BatchNorm1d(512),
      nn.MaxPool2d(kernel_size=(2,2), stride=(2,2)),
      nn.ReLU())
    
    self.conv2_skip = nn.Sequential(
      nn.Conv2d(256, 512, kernel_size=self.k1, padding=(1,1)),
      nn.ReLU())
    
    self.conv3 = nn.Sequential(
      nn.Conv2d(128, 256, kernel_size=self.k1, padding=(1,1)),
      # nn.BatchNorm1d(512),
      nn.ReLU())
    
    self.conv4 = nn.Sequential(
      nn.Conv2d(256, 512, kernel_size=self.k1, padding=1),
      # nn.BatchNorm1d(256),
      nn.ReLU())
    
    self.conv4a = nn.Sequential(
      nn.Conv2d(512, 256, kernel_size=self.k1, padding=1),
      # nn.BatchNorm1d(256),
      nn.ReLU())
    
    self.conv5a = nn.Sequential(
      nn.Conv2d(128, 64, kernel_size=self.k1, padding=1),
      # nn.BatchNorm1d(256),
      nn.ReLU())
    
    self.conv5b = nn.Sequential(
      nn.Conv2d(64, 1, kernel_size=self.k1, padding=1),
      # nn.BatchNorm1d(256),
      nn.ReLU())

    self.conv5c = nn.Sequential(
      nn.Conv2d(32, 1, kernel_size=self.k1, padding=1),
      nn.ReLU())
    
    
    
    self.up1 = nn.ConvTranspose2d(in_channels=256, out_channels=256, kernel_size=2, stride=2)
    self.up2 = nn.ConvTranspose2d(in_channels=640, out_channels=128, kernel_size=2, stride=2)
    

  def forward(self, x):

    skip1 = self.conv1_skip(x)

    x = self.conv1(x)
    # print(f"conv1 size: {x.shape}")
    x = self.conv1b(x)
  
    # print(f"conv1b size: {x.shape}")
    x = self.conv1c(x)
    # print(f"conv1c size: {x.shape}")

    # x = self.conv1d(x)

    # skip2 = self.conv2_skip(x)
    # print(f"skip2 size: {x.shape}")

    x = self.conv2(x)
    # print(f"conv2 size: {x.shape}")


    x = self.conv3(x)
    # print(f"conv3 size: {x.shape}")
    # print(f"0: {x.shape}")

    x = self.up1(x)
    # print(f"upsam1 size: {x.shape}")

    # x = torch.cat((x, skip2))  # Concatenate along channel dimension
    # print(f"concat1 output: {x.shape}")
    x = self.conv4(x)
    # print(f"conv4 size: {x.shape}")
    # x = self.conv5(x)
    # print(f"2: {x.shape}")
    
    # print(f"3: {x.shape}")
    x = torch.cat((x, skip1))  # Concatenate along channel dimension
    # print(f"concat output: {x.shape}")
    x = self.up2(x)
    # print(f"upsamp2 size: {x.shape}")
    
    x = self.conv5a(x)
    x = self.conv5b(x)
    # x = self.conv5c(x)
    # print(f"4: {x.shape}")
    
    return x

# %% [markdown]
# #### JennaNet

# %%
class JennaNet(nn.Module):
  def __init__(self):
    super(JennaNet, self).__init__()
  
    self.conv1 = nn.Conv2d(1, 16, kernel_size=(3,3), padding=(1,1))
    self.conv2 = nn.Conv2d(16, 32, kernel_size=(3,3), padding=(1,1))
    self.conv3 = nn.Conv2d(32, 64, kernel_size=(3,3), padding=(1,1))
    self.conv4 = nn.Conv2d(64, 128, kernel_size=(3,3), padding=(1,1))

    self.conv5 = nn.Conv2d(128, 64, kernel_size=(3,3), padding=(1,1))
    self.conv6 = nn.Conv2d(64, 32, kernel_size=(3,3), padding=(1,1))
    self.conv7 = nn.Conv2d(32, 16, kernel_size=(3,3), padding=(1,1))
    self.conv8 = nn.Conv2d(16, 1, kernel_size=(3,3), padding=(1,1))

  def forward(self, x):

    x = self.conv1(x)
    x = self.conv2(x)
    x = self.conv3(x)
    x = self.conv4(x)
    x = self.conv5(x)
    x = self.conv6(x)
    x = self.conv7(x)
    x = self.conv8(x)
    
    return x

# %% [markdown]
# #### DemaNet

# %%
class DemaNet(nn.Module):
    def __init__(self):
        super(DemaNet, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(1, 128, kernel_size=(7,7), padding=3, stride=1),
            nn.ReLU())
        
        self.conv2 = nn.Sequential(
            nn.Conv2d(128, 128, kernel_size=(7,7), padding=3, stride=1),
            nn.ReLU())

        self.conv3 = nn.Sequential(
            nn.Conv2d(128, 128, kernel_size=(7,7), padding=3, stride=1),
            nn.ReLU())
        
        self.conv4 = nn.Sequential(
            nn.Conv2d(128, 128, kernel_size=(7,7), padding=3, stride=1),
            nn.ReLU())

        self.conv5 = nn.Sequential(
            nn.Conv2d(128, 1, kernel_size=(7,7), padding=3, stride=1))


        self.conv_skip1 = nn.Conv2d(1, 1, kernel_size=(1,1), stride=(1,1))


        self.conv6 = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=(3,3), padding=1, stride=1))
        

        self.conv7 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=(7,7), padding=3, stride=1),
            nn.BatchNorm1d(128),
            nn.ReLU())
        
        self.conv8 = nn.Sequential(
            nn.Conv2d(128, 128, kernel_size=(7,7), padding=3, stride=1),
            nn.BatchNorm1d(128),
            nn.ReLU())
        
        self.conv9 = nn.Sequential(
            nn.Conv2d(128, 128, kernel_size=(7,7), padding=3, stride=1),
            nn.BatchNorm1d(128),
            nn.ReLU())
        
        self.conv10 = nn.Sequential(
            nn.Conv2d(128, 128, kernel_size=(7,7), padding=3, stride=1),
            nn.BatchNorm1d(128),
            nn.ReLU())
        
        self.conv11 = nn.Sequential(
            nn.Conv2d(128, 64, kernel_size=(3,3), padding=1, stride=1),
            nn.BatchNorm1d(64)
        )

        
        self.conv_skip2 = nn.Conv2d(64, 64, kernel_size=(1,1), stride=(1,1))

        
        self.conv12 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=(3,3), padding=1, stride=1))
        

        self.conv_skip3 = nn.Conv2d(64, 64, kernel_size=(1,1), stride=(1,1))



        self.conv13 = nn.Sequential(
            nn.Conv2d(64, 1, kernel_size=(7,7), padding=3, stride=1))
        

    def forward(self, x):
        x_previous1 = self.conv_skip1(x) # skip connection
        
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)
        print(f"conv5 size: {x.shape}")
        x = torch.cat((x, x_previous1), dim=1) # Concatenate the main path with the skip connection
        print(f"1st concatenation: {x.shape}")
        x = self.conv6(x)
        print(f"conv6 size: {x.shape}")
        x_previous2 = self.conv_skip2(x) # skip connection
        print(f"skip2_size: {x_previous2.shape}")
        x_previous3 = self.conv_skip3(x) # skip connection
        print(f"skip3_size: {x_previous3.shape}")
        x = self.conv7(x)
        print(f"conv7 size: {x.shape}")
        x = self.conv8(x)
        x = self.conv9(x)
        x = self.conv10(x)
        x = self.conv11(x)
        print(f"conv11 size: {x.shape}")
        x = torch.cat((x, x_previous2), dim=1)
        print(f"2nd concat: {x.shape}")
        x = self.conv12(x)
        print(f"conv12 size: {x.shape}")
        x = torch.cat((x, x_previous3), dim=1)
        print(f"3rd concat: {x.shape}")
        x = self.conv13(x)
        print(f"conv13 size: {x.shape}")
        return x

# %% [markdown]
# #### MRDAN

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch
from torchsummary import summary
from modelDefinitions.basicBlocks import *    



class DynamicResAttNet(nn.Module):
    def __init__(self, channels, num_of_layers=17):
        super(DynamicResAttNet, self).__init__()
        kernel_size = 3
        padding = 1
        features = 64
        layers = []
        layers.append(nn.Conv2d(in_channels=channels, out_channels=features, kernel_size=kernel_size, padding=padding, bias=False))
        layers.append(nn.ReLU(inplace=True))
        self.inputLayer = nn.Sequential(*layers)

        block1 = []

        for _ in range(5):
            block1.append(Dynamic_conv2d(in_planes=features, out_planes=features, kernel_size=kernel_size, padding=padding))
            block1.append(nn.BatchNorm2d(features))
            block1.append(nn.ReLU(inplace=True))
        self.block1 = nn.Sequential(*block1)
        self.noiseGate1 = GatedConv2d(in_channels=features, out_channels=features, kernel_size=3, padding=1)
       
        block2 = []

        for _ in range(5):
            block2.append(Dynamic_conv2d(in_planes=features, out_planes=features, kernel_size=kernel_size, padding=padding))
            block2.append(nn.BatchNorm2d(features))
            block2.append(nn.ReLU(inplace=True))
        self.block2 = nn.Sequential(*block2)
        self.noiseGate2 = GatedConv2d(in_channels=features, out_channels=features, kernel_size=3, padding=1)


        block3 = []

        for _ in range(5):
            block3.append(Dynamic_conv2d(in_planes=features, out_planes=features, kernel_size=kernel_size, padding=padding))
            block3.append(nn.BatchNorm2d(features))
            block3.append(nn.ReLU(inplace=True))
        self.block3 = nn.Sequential(*block3)
        self.noiseGate3 = GatedConv2d(in_channels=features, out_channels=features, kernel_size=3, padding=1)

        self.outputLayer = nn.Conv2d(in_channels=features, out_channels=channels, kernel_size=kernel_size, padding=padding, bias=False)
    
    def forward(self, x):
        x0 = self.inputLayer(x)

        x1 = self.block1(x0) + self.noiseGate1(x0)
        x2 = self.block1(x1) + self.noiseGate2(x1)
        x3 = self.block1(x2) + self.noiseGate3(x2)

        return torch.tanh(self.outputLayer(x3))


class DynamicDnCNN(nn.Module):
    def __init__(self, channels, num_of_layers=17):
        super(DynamicDnCNN, self).__init__()
        kernel_size = 3
        padding = 1
        features = 64
        layers = []
        layers.append(nn.Conv2d(in_channels=channels, out_channels=features, kernel_size=kernel_size, padding=padding, bias=False))
        layers.append(nn.ReLU(inplace=True))
        for _ in range(num_of_layers-2):
            layers.append(Dynamic_conv2d(in_planes=features, out_planes=features, kernel_size=kernel_size, padding=padding))
            layers.append(nn.BatchNorm2d(features))
            layers.append(nn.ReLU(inplace=True))
        layers.append(nn.Conv2d(in_channels=features, out_channels=channels, kernel_size=kernel_size, padding=padding, bias=False))
        self.dncnn = nn.Sequential(*layers)
    def forward(self, x):
        out = self.dncnn(x)
        return torch.tanh(out)
#net = DynamicResNet(3)
#summary(net, input_size = (3, 128, 128))
#print ("reconstruction network")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 4
#       2 import torch.nn.functional as F
#       3 import torch
# ----> 4 from torchsummary import summary
#       5 from modelDefinitions.basicBlocks import *
#       9 class DynamicResAttNet(nn.Module):
#
# ModuleNotFoundError: No module named 'torchsummary'

# %% [markdown]
# ### Architecture Todo:
#
# #### - mini batch?
# #### - batch norm
# #### - max pool
# #### - skip connection

# %% [markdown]
# ___
# ### Define NMSE and SSIM functions

# %%
def calculateNMSE(true_img, noisy_img):
    mse = torch.sqrt(torch.sum((true_img - noisy_img) ** 2))    
    nmse = mse / torch.sqrt(torch.sum(true_img ** 2))
    return 20*np.log10(nmse.detach().item())

def calculateSSIM(true_img, noisy_img):

    true_img = np.abs(true_img.detach()).squeeze().numpy()
    noisy_img = np.abs(noisy_img.detach()).squeeze().numpy()
    img_range = np.max(true_img) - np.min(true_img)

    return ssim(true_img, noisy_img, data_range=img_range)

# %% [markdown]
# ___
# ### Create a function to execute training. Note, we will call this function later.

# %%
def train_model(model, opt, criterion, train_loader, val_loader, num_epoch, noise_std):
    avg_train_losses = []
    avg_nmse_losses = []
    val_nmse_per_epoch = []  # List to store validation NMSE per epoch

    avg_train_ssim_losses = [] 
    val_ssim_per_epoch = [] 

    for epoch in range(num_epoch):
        model.train()
        total_train_loss = 0
        total_nmse_loss = 0

        total_ssim_loss = 0
        avg_batch_train_nmse_loss = 0
        avg_batch_train_ssim_loss = 0

        for i, y_tr_batch in enumerate(train_loader):
            # Train with noisy data
            noise = torch.randn_like(y_tr_batch) * noise_std
            x_tr_batch = y_tr_batch + noise
            
            # rand_speckle = np.random.uniform(0.01, 0.05)
            # x_tr_batch = add_mixed_noise(y_tr_batch, 0.1, rand_speckle)

            
           
            # Test teach base 
            num_batch = y_tr_batch.shape[0]
            for j in range(num_batch):

                opt.zero_grad()
                y_hat_tr_batch_j = model(x_tr_batch[j]) # run the j-th image in the batch through the model

                loss = criterion(y_hat_tr_batch_j, y_tr_batch[j]) # calculates loss for j-th image in batch
                loss.backward()
                opt.step()
                # print(y_tr_batch.shape)
                total_train_loss += loss.item() # sum the loss

                # Aggregate NMSE and SSIM
                total_nmse_loss += calculateNMSE(y_tr_batch[j], y_hat_tr_batch_j)
                total_ssim_loss += calculateSSIM(y_tr_batch[j], y_hat_tr_batch_j)

            # Calculate average across samples in batch training NMSE and SSIM loss
            avg_batch_train_nmse_loss = total_nmse_loss / num_batch
            avg_batch_train_ssim_loss = total_ssim_loss / num_batch

            if (i + 1) % 10 == 0:
                print(f'Epoch {epoch+1}, Iteration {i+1}, '
                      f'MSE: {loss.item():.6f}')

        # Calculate average MSE, NMSE, and SSIM for everything across entire training set
        avg_train_loss = total_train_loss / len(train_loader)
        avg_train_losses.append(avg_train_loss)

        avg_nmse_loss = avg_batch_train_nmse_loss / len(train_loader)
        avg_nmse_losses.append(avg_nmse_loss)
        print(f'NMSE: {avg_nmse_loss:.6f}')

        avg_train_ssim_loss = avg_batch_train_ssim_loss / len(train_loader)
        avg_train_ssim_losses.append(avg_train_ssim_loss)

        # Calculate validation NMSE per epoch
        val_epoch_nmse = 0
        val_epoch_ssim = 0
        avg_batch_val_nmse = 0
        avg_batch_val_ssim = 0


        for y_val_batch in val_loader:

            # Add noise to validation batch
            noise_val = torch.randn_like(y_val_batch) * noise_std
            x_val_batch = y_val_batch.detach() + noise_val

            num_batch = y_val_batch.shape[0]
            for j in range(num_batch):
                y_hat_val_batch_j = model(x_val_batch[j])
                val_epoch_nmse += calculateNMSE(y_val_batch[j], y_hat_val_batch_j)
                val_epoch_ssim += calculateSSIM(y_val_batch[j], y_hat_val_batch_j)
            
            avg_batch_val_nmse = val_epoch_nmse / num_batch
            avg_batch_val_ssim = val_epoch_ssim / num_batch
                
        val_nmse_per_epoch.append(avg_batch_val_nmse / len(val_loader))
        val_ssim_per_epoch.append(avg_batch_val_ssim / len(val_loader))

    # Plotting (combine training and validation NMSE on same plot)
    fig, ax = plt.subplots(2,1,figsize=(7, 6))
    epochs = range(1, num_epoch + 1)  # X-axis for training NMSE

    # ax[0].plot(epochs, avg_train_losses, label='Training')

    # ax[0].set_xlabel('Epochs')
    # ax[0].set_ylabel('MSE Loss')
    # # No need for log scale here, adjust based on your needs
    # ax[0].set_title('Training MSE')
    # ax[0].grid(True)
    # ax[0].legend()

    ax[0].plot(epochs, avg_nmse_losses, label='Training')
    ax[0].plot(epochs, val_nmse_per_epoch, label='Validation')

    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('NMSE Loss')
    # No need for log scale here, adjust based on your needs
    ax[0].set_title('Training and Validation NMSE')
    ax[0].grid(True)
    ax[0].legend()

    ax[1].plot(epochs, avg_train_ssim_losses, label='Training')
    ax[1].plot(epochs, val_ssim_per_epoch, label='Validation')

    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('SSIM')
    # No need for log scale here, adjust based on your needs
    ax[1].set_title('Training and Validation SSIM')
    ax[1].grid(True)
    ax[1].legend()

    plt.tight_layout()
    plt.show()

    

    # TODO:Output Final NMSE, SSIM, and Grade

# %% [markdown]
# ___
# ### Now, let us define hyperparameters and train the network.
#
# #### Note, in addition to the parameters that controls the network architecture or the training process, you need to select/initialize (i) a data loader, (ii) a model, (iii) an optimizer, and (iv) a loss function.

# %%
batch_size = 2 # Number of complete images in each batch
lr = 1e-4  # Learning rate
sig = 0.1  # Noise std
num_epoch = 100 # Epochs

# Model, criterion, and optimizer
train_loader = create_loader(train_dataset, batch_size)
val_loader = create_loader(val_dataset, 1)

model = MihirNet2() # Pick a model
opt = optim.Adam(model.parameters(), lr=lr) # Pick an optimizer
criterion = nn.MSELoss() # Pick a loss function

# Let's train the model
train_model(model, opt, criterion, train_loader, val_loader, num_epoch, noise_std=sig)
# Out:
# Epoch 1, Iteration 10, MSE: 0.020959
# Epoch 1, Iteration 20, MSE: 0.007603
# NMSE: -6.577220
# Epoch 2, Iteration 10, MSE: 0.001415
# Epoch 2, Iteration 20, MSE: 0.001862
# NMSE: -14.692646
# Epoch 3, Iteration 10, MSE: 0.001204
# Epoch 3, Iteration 20, MSE: 0.001562
# NMSE: -15.853908
# Epoch 4, Iteration 10, MSE: 0.001538
# Epoch 4, Iteration 20, MSE: 0.001023
# NMSE: -16.232777
# Epoch 5, Iteration 10, MSE: 0.001252
# Epoch 5, Iteration 20, MSE: 0.001221
# NMSE: -16.492050
# Epoch 6, Iteration 10, MSE: 0.001655
# Epoch 6, Iteration 20, MSE: 0.001424
# NMSE: -16.701713
# Epoch 7, Iteration 10, MSE: 0.001209
# Epoch 7, Iteration 20, MSE: 0.001222
# NMSE: -16.816721
# Epoch 8, Iteration 10, MSE: 0.001137
# Epoch 8, Iteration 20, MSE: 0.001157
# NMSE: -16.938336
# Epoch 9, Iteration 10, MSE: 0.001175
# Epoch 9, Iteration 20, MSE: 0.001305
# NMSE: -16.995029
# Epoch 10, Iteration 10, MSE: 0.001152
# Epoch 10, Iteration 20, MSE: 0.001392
# NMSE: -17.074782
# Epoch 11, Iteration 10, MSE: 0.001223
# Epoch 11, Iteration 20, MSE: 0.001348
# NMSE: -17.121312
# Epoch 12, Iteration 10, MSE: 0.001202
# Epoch 12, Iteration 20, MSE: 0.001068
# NMSE: -17.187433
# Epoch 13, Iteration 10, MSE: 0.001254
# Epoch 13, Iteration 20, MSE: 0.001087
# NMSE: -17.231204
# Epoch 14, Iteration 10, MSE: 0.001132
# Epoch 14, Iteration 20, MSE: 0.000888
# NMSE: -17.275676
# Epoch 15, Iteration 10, MSE: 0.001381
# Epoch 15, Iteration 20, MSE: 0.001184
# NMSE: -17.318243
# Epoch 16, Iteration 10, MSE: 0.000959
# Epoch 16, Iteration 20, MSE: 0.001160
# NMSE: -17.371151
# Epoch 17, Iteration 10, MSE: 0.001012
# Epoch 17, Iteration 20, MSE: 0.001131
# NMSE: -17.403468
# Epoch 18, Iteration 10, MSE: 0.001129
# Epoch 18, Iteration 20, MSE: 0.001193
# NMSE: -17.459023
# Epoch 19, Iteration 10, MSE: 0.001284
# Epoch 19, Iteration 20, MSE: 0.001087
# NMSE: -17.497642
# Epoch 20, Iteration 10, MSE: 0.001026
# Epoch 20, Iteration 20, MSE: 0.001219
# NMSE: -17.538440
# Epoch 21, Iteration 10, MSE: 0.000944
# Epoch 21, Iteration 20, MSE: 0.001119
# NMSE: -17.580728
# Epoch 22, Iteration 10, MSE: 0.001140
# Epoch 22, Iteration 20, MSE: 0.001154
# NMSE: -17.611658
# Epoch 23, Iteration 10, MSE: 0.000922
# Epoch 23, Iteration 20, MSE: 0.001216
# NMSE: -17.617938
# Epoch 24, Iteration 10, MSE: 0.001143
# Epoch 24, Iteration 20, MSE: 0.001301
# NMSE: -17.678139
# Epoch 25, Iteration 10, MSE: 0.000952
# Epoch 25, Iteration 20, MSE: 0.000858
# NMSE: -17.723293
# Epoch 26, Iteration 10, MSE: 0.001036
# Epoch 26, Iteration 20, MSE: 0.000934
# NMSE: -17.756539
# Epoch 27, Iteration 10, MSE: 0.001077
# Epoch 27, Iteration 20, MSE: 0.001229
# NMSE: -17.804740
# Epoch 28, Iteration 10, MSE: 0.000627
# Epoch 28, Iteration 20, MSE: 0.001085
# NMSE: -17.823227
# Epoch 29, Iteration 10, MSE: 0.001001
# Epoch 29, Iteration 20, MSE: 0.001022
# NMSE: -17.834100
# Epoch 30, Iteration 10, MSE: 0.001117
# Epoch 30, Iteration 20, MSE: 0.001076
# NMSE: -17.877758
# Epoch 31, Iteration 10, MSE: 0.000586
# Epoch 31, Iteration 20, MSE: 0.001001
# NMSE: -17.904085
# Epoch 32, Iteration 10, MSE: 0.001061
# Epoch 32, Iteration 20, MSE: 0.000790
# NMSE: -17.911978
# Epoch 33, Iteration 10, MSE: 0.000934
# Epoch 33, Iteration 20, MSE: 0.000944
# NMSE: -17.961810
# Epoch 34, Iteration 10, MSE: 0.001027
# Epoch 34, Iteration 20, MSE: 0.000965
# NMSE: -17.994107
# Epoch 35, Iteration 10, MSE: 0.000938
# Epoch 35, Iteration 20, MSE: 0.000904
# NMSE: -17.979629
# Epoch 36, Iteration 10, MSE: 0.001032
# Epoch 36, Iteration 20, MSE: 0.000786
# NMSE: -18.031676
# Epoch 37, Iteration 10, MSE: 0.000776
# Epoch 37, Iteration 20, MSE: 0.000592
# NMSE: -18.056548
# Epoch 38, Iteration 10, MSE: 0.001110
# Epoch 38, Iteration 20, MSE: 0.000693
# NMSE: -18.061999
# Epoch 39, Iteration 10, MSE: 0.001039
# Epoch 39, Iteration 20, MSE: 0.000956
# NMSE: -18.092897
# Epoch 40, Iteration 10, MSE: 0.001000
# Epoch 40, Iteration 20, MSE: 0.000937
# NMSE: -18.143567
# Epoch 41, Iteration 10, MSE: 0.000939
# Epoch 41, Iteration 20, MSE: 0.000684
# NMSE: -18.147394
# Epoch 42, Iteration 10, MSE: 0.000950
# Epoch 42, Iteration 20, MSE: 0.000950
# NMSE: -18.129477
# Epoch 43, Iteration 10, MSE: 0.001087
# Epoch 43, Iteration 20, MSE: 0.000737
# NMSE: -18.153214
# Epoch 44, Iteration 10, MSE: 0.000909
# Epoch 44, Iteration 20, MSE: 0.001010
# NMSE: -18.157129
# Epoch 45, Iteration 10, MSE: 0.000996
# Epoch 45, Iteration 20, MSE: 0.001142
# NMSE: -18.182513
# Epoch 46, Iteration 10, MSE: 0.000851
# Epoch 46, Iteration 20, MSE: 0.001030
# NMSE: -18.215569
# Epoch 47, Iteration 10, MSE: 0.000871
# Epoch 47, Iteration 20, MSE: 0.000956
# NMSE: -18.271992
# Epoch 48, Iteration 10, MSE: 0.000722
# Epoch 48, Iteration 20, MSE: 0.000876
# NMSE: -18.273743
# Epoch 49, Iteration 10, MSE: 0.000928
# Epoch 49, Iteration 20, MSE: 0.000808
# NMSE: -18.287644
# Epoch 50, Iteration 10, MSE: 0.000659
# Epoch 50, Iteration 20, MSE: 0.001120
# NMSE: -18.318439
# Epoch 51, Iteration 10, MSE: 0.000960
# Epoch 51, Iteration 20, MSE: 0.000560
# NMSE: -18.309220
# Epoch 52, Iteration 10, MSE: 0.000830
# Epoch 52, Iteration 20, MSE: 0.000782
# NMSE: -18.333780
# Epoch 53, Iteration 10, MSE: 0.001049
# Epoch 53, Iteration 20, MSE: 0.000824
# NMSE: -18.377054
# Epoch 54, Iteration 10, MSE: 0.000813
# Epoch 54, Iteration 20, MSE: 0.000940
# NMSE: -18.405576
# Epoch 55, Iteration 10, MSE: 0.000893
# Epoch 55, Iteration 20, MSE: 0.000808
# NMSE: -18.424707
# Epoch 56, Iteration 10, MSE: 0.000713
# Epoch 56, Iteration 20, MSE: 0.001029
# NMSE: -18.447669
# Epoch 57, Iteration 10, MSE: 0.000951
# Epoch 57, Iteration 20, MSE: 0.000716
# NMSE: -18.450499
# Epoch 58, Iteration 10, MSE: 0.000908
# Epoch 58, Iteration 20, MSE: 0.000863
# NMSE: -18.494164
# Epoch 59, Iteration 10, MSE: 0.000921
# Epoch 59, Iteration 20, MSE: 0.000625
# NMSE: -18.516958
# Epoch 60, Iteration 10, MSE: 0.000905
# Epoch 60, Iteration 20, MSE: 0.000897
# NMSE: -18.540515
# Epoch 61, Iteration 10, MSE: 0.000915
# Epoch 61, Iteration 20, MSE: 0.000481
# NMSE: -18.584884
# Epoch 62, Iteration 10, MSE: 0.000908
# Epoch 62, Iteration 20, MSE: 0.000714
# NMSE: -18.526259
# Epoch 63, Iteration 10, MSE: 0.000964
# Epoch 63, Iteration 20, MSE: 0.000793
# NMSE: -18.592238
# Epoch 64, Iteration 10, MSE: 0.000895
# Epoch 64, Iteration 20, MSE: 0.000867
# NMSE: -18.666050
# Epoch 65, Iteration 10, MSE: 0.001077
# Epoch 65, Iteration 20, MSE: 0.000870
# NMSE: -18.694790
# Epoch 66, Iteration 10, MSE: 0.000656
# Epoch 66, Iteration 20, MSE: 0.000756
# NMSE: -18.688929
# Epoch 67, Iteration 10, MSE: 0.000956
# Epoch 67, Iteration 20, MSE: 0.000867
# NMSE: -18.731755
# Epoch 68, Iteration 10, MSE: 0.000900
# Epoch 68, Iteration 20, MSE: 0.000608
# NMSE: -18.737956
# Epoch 69, Iteration 10, MSE: 0.000680
# Epoch 69, Iteration 20, MSE: 0.000653
# NMSE: -18.767276
# Epoch 70, Iteration 10, MSE: 0.000748
# Epoch 70, Iteration 20, MSE: 0.000584
# NMSE: -18.778338
# Epoch 71, Iteration 10, MSE: 0.000855
# Epoch 71, Iteration 20, MSE: 0.000888
# NMSE: -18.796540
# Epoch 72, Iteration 10, MSE: 0.000748
# Epoch 72, Iteration 20, MSE: 0.000990
# NMSE: -18.729709
# Epoch 73, Iteration 10, MSE: 0.000628
# Epoch 73, Iteration 20, MSE: 0.000855
# NMSE: -18.791366
# Epoch 74, Iteration 10, MSE: 0.000826
# Epoch 74, Iteration 20, MSE: 0.000876
# NMSE: -18.829343
# Epoch 75, Iteration 10, MSE: 0.001002
# Epoch 75, Iteration 20, MSE: 0.000620
# NMSE: -18.891975
# Epoch 76, Iteration 10, MSE: 0.000803
# Epoch 76, Iteration 20, MSE: 0.000703
# NMSE: -18.885485
# Epoch 77, Iteration 10, MSE: 0.000749
# Epoch 77, Iteration 20, MSE: 0.000803
# NMSE: -18.838298
# Epoch 78, Iteration 10, MSE: 0.000908
# Epoch 78, Iteration 20, MSE: 0.000866
# NMSE: -18.879377
# Epoch 79, Iteration 10, MSE: 0.000711
# Epoch 79, Iteration 20, MSE: 0.000764
# NMSE: -18.917772
# Epoch 80, Iteration 10, MSE: 0.001012
# Epoch 80, Iteration 20, MSE: 0.000786
# NMSE: -18.869227
# Epoch 81, Iteration 10, MSE: 0.000995
# Epoch 81, Iteration 20, MSE: 0.000883
# NMSE: -18.879786
# Epoch 82, Iteration 10, MSE: 0.000919
# Epoch 82, Iteration 20, MSE: 0.000705
# NMSE: -18.942363
# Epoch 83, Iteration 10, MSE: 0.000613
# Epoch 83, Iteration 20, MSE: 0.000672
# NMSE: -18.945466
# Epoch 84, Iteration 10, MSE: 0.000794
# Epoch 84, Iteration 20, MSE: 0.000804
# NMSE: -18.972478
# Epoch 85, Iteration 10, MSE: 0.000821
# Epoch 85, Iteration 20, MSE: 0.000987
# NMSE: -18.964162
# Epoch 86, Iteration 10, MSE: 0.000817
# Epoch 86, Iteration 20, MSE: 0.000822
# NMSE: -18.958953
# Epoch 87, Iteration 10, MSE: 0.000570
# Epoch 87, Iteration 20, MSE: 0.000719
# NMSE: -19.003784
# Epoch 88, Iteration 10, MSE: 0.000813
# Epoch 88, Iteration 20, MSE: 0.000891
# NMSE: -18.983137
# Epoch 89, Iteration 10, MSE: 0.000775
# Epoch 89, Iteration 20, MSE: 0.000746
# NMSE: -18.996499
# Epoch 90, Iteration 10, MSE: 0.000555
# Epoch 90, Iteration 20, MSE: 0.000851
# NMSE: -18.999775
# Epoch 91, Iteration 10, MSE: 0.000993
# Epoch 91, Iteration 20, MSE: 0.000870
# NMSE: -18.963095
# Epoch 92, Iteration 10, MSE: 0.000845
# Epoch 92, Iteration 20, MSE: 0.000559
# NMSE: -18.999264
# Epoch 93, Iteration 10, MSE: 0.000780
# Epoch 93, Iteration 20, MSE: 0.000566
# NMSE: -19.024228
# Epoch 94, Iteration 10, MSE: 0.000807
# Epoch 94, Iteration 20, MSE: 0.000714
# NMSE: -19.038247
# Epoch 95, Iteration 10, MSE: 0.000797
# Epoch 95, Iteration 20, MSE: 0.000829
# NMSE: -19.028376
# Epoch 96, Iteration 10, MSE: 0.000808
# Epoch 96, Iteration 20, MSE: 0.000831
# NMSE: -18.990175
# Epoch 97, Iteration 10, MSE: 0.000828
# Epoch 97, Iteration 20, MSE: 0.000855
# NMSE: -19.049936
# Epoch 98, Iteration 10, MSE: 0.000796
# Epoch 98, Iteration 20, MSE: 0.000843
# NMSE: -19.039407
# Epoch 99, Iteration 10, MSE: 0.000616
# Epoch 99, Iteration 20, MSE: 0.000713
# NMSE: -19.066180
# Epoch 100, Iteration 10, MSE: 0.000683
# Epoch 100, Iteration 20, MSE: 0.000706
# NMSE: -19.085060

# %%
# save the model
# model = MihirNet2() # Pick a model
# sig = 0.1
# PATH = 'MihirNet2_75e.pt'
# torch.save(model.state_dict(), PATH)

# %%
model.parameters
# Out:
# <bound method Module.parameters of MihirNet2(
#   (conv1_skip): Sequential(
#     (0): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#   )
#   (conv1): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#   )
#   (conv1b): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv1c): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv1d): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#   )
#   (conv2_skip): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv4a): Sequential(
#     (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv5a): Sequential(
#     (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv5b): Sequential(
#     (0): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv5c): Sequential(
#     (0): Conv2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (up1): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#   (up2): ConvTranspose2d(640, 128, kernel_size=(2, 2), stride=(2, 2))
# )>

# %% [markdown]
# ___
# ### Apply it to one of the validation image

# %%
val_dataset = TIFFDataset('val-clean-tif', transform=transform) # Create the dataset for validation images
val_clean = val_dataset[0] # Load one clean image from the validation dataset
val_noisy = val_clean + (torch.randn_like(val_clean) * sig) # Add noise to the clean image
val_denoised = model(val_noisy).detach() # Denoise the noisy image using the trained model


# Your existing code to generate the figure and axes
fig, ax = plt.subplots(2, 3, figsize=(10, 7))

# Plot clean image
ax[0, 0].imshow(np.abs(val_clean).squeeze().numpy(), cmap='gray', vmin=0, vmax=1)
ax[0, 0].set_title('clean image')
ax[0, 0].axis('off')

# Plot noisy image
ax[0, 1].imshow(np.abs(val_noisy).squeeze().numpy(), cmap='gray', vmin=0, vmax=1)
ax[0, 1].set_title('noisy image')
ax[0, 1].axis('off')

# Plot denoised image
ax[0, 2].imshow(np.abs(val_denoised).squeeze().numpy(), cmap='gray', vmin=0, vmax=1)
ax[0, 2].set_title('denoised image')
ax[0, 2].axis('off')

# Plot corresponding error images
ax[1, 0].imshow(3*np.abs(val_clean - val_clean).squeeze().numpy(), cmap='gray', vmin=0, vmax=1)
ax[1, 0].axis('off')
ax[1, 0].text(0.02, 0.98, r'$\times 3$', transform=ax[1, 0].transAxes, fontsize=14, va='top', ha='left', color='white')

ax[1, 1].imshow(3*np.abs(val_clean - val_noisy).squeeze().numpy(), cmap='gray', vmin=0, vmax=1)
ax[1, 1].axis('off')
ax[1, 1].text(0.02, 0.98, r'$\times 3$', transform=ax[1, 1].transAxes, fontsize=14, va='top', ha='left', color='white')

ax[1, 2].imshow(3*np.abs(val_clean - val_denoised).squeeze().numpy(), cmap='gray', vmin=0, vmax=1)
ax[1, 2].axis('off')
ax[1, 2].text(0.02, 0.98, r'$\times 3$', transform=ax[1, 2].transAxes, fontsize=14, va='top', ha='left', color='white')


plt.tight_layout()
plt.show()

# %% [markdown]
# # Model Evaluation

# %%
# Load model

# PATH = 'MihirNet2_75.pt'
# model = MihirNet2()
# model.load_state_dict(torch.load(PATH))
# model.eval()

# %% [markdown]
# ### Grade Calculation

# %%
# Load Testing Data

test_dataset = TIFFDataset('test-clean-tif', transform=transform) # Create the dataset for testing images

# %%
# Grade Calculation Code

NMSE_te = 0
NMSE_te_sum = 0
SSIM_te = 0
SSIM_te_sum = 0

NMSE_va = 0
NMSE_va_sum = 0
SSIM_va = 0
SSIM_va_sum = 0

sig = 0.1

for val_clean in val_dataset:
    # add random noise
    val_noisy = val_clean + (torch.randn_like(val_clean) * sig)

    # remove noise with model
    val_denoised = model(val_noisy)

    NMSE_va_sum += calculateNMSE(val_clean, val_denoised)
    SSIM_va_sum += calculateSSIM(val_clean, val_denoised)

for test_clean in test_dataset:
    # add random noise
    test_noisy = test_clean + (torch.randn_like(test_clean) * sig)

    # remove noise with model
    test_denoised = model(test_noisy)

    NMSE_te_sum += calculateNMSE(test_clean, test_denoised)
    SSIM_te_sum += calculateSSIM(test_clean, test_denoised)


NMSE_va = NMSE_va_sum / len(val_dataset)
SSIM_va = SSIM_va_sum / len(val_dataset)

NMSE_te = NMSE_te_sum / len(test_dataset)
SSIM_te = SSIM_te_sum / len(test_dataset)

print(f"NMSE_va: {NMSE_va:0.3f}")
print(f"SSIM_va: {SSIM_va:0.3f}")
print()
print(f"NMSE_te: {NMSE_te:0.3f}")
print(f"SSIM_te: {SSIM_te:0.3f}")
print()

NMSE_ref = -20.7 # change to be max from all teams

grade = min((100 - 5*(NMSE_te - NMSE_ref), 100)) # TODO: change to testing set
print(f"Grade: {grade:0.3f}")
# Out:
# NMSE_va: -19.005
# SSIM_va: 0.858
#
# NMSE_te: -19.229
# SSIM_te: 0.864
#
# Grade: 92.645

# %% [markdown]
# ### Trivial Net
#
# ##### NMSE_te: -14.651 (validation set)
# ##### SSIM_te: 0.594 (validation set)
# ##### Grade: 69.755

# %% [markdown]
# lr = 1e-3  # Learning rate
# sig = 0.1  # Noise std
# num_epoch = 20  # Epochs

# %% [markdown]
# ### MihirNet1
#
# ##### NMSE_te: -18.200 (validation set)
# ##### SSIM_te: 0.835 (validation set)
# ##### Grade: 87.500

# %% [markdown]
# # Questions

# %% [markdown]
# #### Is the NMSE being calculated correctly?
# #### Is the SNR too high? How can the SNR calculation be modified?

# %% [markdown]
# ## Things to try
#
#
# ### add more feature extraction (like edge detection)
#
# ### adding more random noise
#
# ### dimensionality reduction of images
#
# ### dense network
#
# ### create artificial testing set (with varying noise)
#
# ### use diffusion models
